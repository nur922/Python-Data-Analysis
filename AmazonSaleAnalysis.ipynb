# %%
import numpy as np
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("AmazonSaleReport.csv")

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df.tail()
# Out:
#          index             Order ID      Date   Status Fulfilment  \
# 128970  128970  406-6001380-7673107  05-31-22  Shipped     Amazon
# 128971  128971  402-9551604-7544318  05-31-22  Shipped     Amazon
# 128972  128972  407-9547469-3152358  05-31-22  Shipped     Amazon
# 128973  128973  402-6184140-0545956  05-31-22  Shipped     Amazon
# 128974  128974  408-7436540-8728312  05-31-22  Shipped     Amazon
#
#        Sales Channel  ship-service-level    Style             SKU  \
# 128970      Amazon.in          Expedited  JNE3697   JNE3697-KR-XL
# 128971      Amazon.in          Expedited   SET401  SET401-KR-NP-M
# 128972      Amazon.in          Expedited    J0157    J0157-DR-XXL
# 128973      Amazon.in          Expedited    J0012    J0012-SKD-XS
# 128974      Amazon.in          Expedited    J0003     J0003-SET-S
#
#              Category  ... currency  Amount  ship-city    ship-state  \
# 128970          kurta  ...      INR   517.0  HYDERABAD     TELANGANA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
df=df.drop("fulfilled-by" , axis=1)

# %%
df["Courier Status"].fillna(df["Courier Status"].mode()[0] , inplace=True)

# %%
df=df.drop(["B2B","Unnamed: 22","index"], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128975 non-null  object
#  1   Date                128975 non-null  object
#  2   Status              128975 non-null  object
#  3   Fulfilment          128975 non-null  object
#  4   Sales Channel       128975 non-null  object
#  5   ship-service-level  128975 non-null  object
#  6   Style               128975 non-null  object
#  7   SKU                 128975 non-null  object
#  8   Category            128975 non-null  object
#  9   Size                128975 non-null  object
#  10  ASIN                128975 non-null  object
#  11  Courier Status      128975 non-null  object
#  12  Qty                 128975 non-null  int64
#  13  currency            121180 non-null  object
#  14  Amount              121180 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status            0
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# dtype: int64

# %%
df["currency"].fillna(df["currency"].mode()[0], inplace=True)

# %%
df["Amount"].fillna(df["Amount"].mode()[0], inplace=True)

# %%
df['ship-city'].fillna(df['ship-city'].mode()[0],inplace=True)
df['ship-state'].fillna(df['ship-state'].mode()[0],inplace=True)
df['ship-postal-code'].fillna(df['ship-postal-code'].mode()[0],inplace=True)
df['ship-country'].fillna(df['ship-country'].mode()[0],inplace=True)
df['promotion-ids'].fillna(df['promotion-ids'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Style                 0
# SKU                   0
# Category              0
# Size                  0
# ASIN                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# promotion-ids         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 6

# %%
df.shape
# Out:
# (128975, 20)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (128969, 20)

# %%
df.columns
# Out:
# Index(['Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids'],
#       dtype='object')

# %%
df.sample()
# Out:
#                   Order ID      Date   Status Fulfilment Sales Channel   \
# 47989  402-9521336-1166701  04-01-22  Shipped     Amazon      Amazon.in
#
#       ship-service-level    Style             SKU Category Size        ASIN  \
# 47989          Expedited  JNE3641  JNE3641-TP-N-S      Top    S  B08ZJ375LH
#
#       Courier Status  Qty currency  Amount                 ship-city  \
# 47989        Shipped    1      INR   354.0  LAKHIPUR CACHAR DISTRICT
#
#       ship-state  ship-postal-code ship-country  \
# 47989      ASSAM          788103.0           IN
#
#                                       promotion-ids
# 47989  IN Core Free Shipping 2015/04/08 23-48-5-108

# %%
df["Fulfilment"].value_counts()
# Out:
# Amazon      89692
# Merchant    39277
# Name: Fulfilment, dtype: int64

# %%
df["currency"].value_counts()
# Out:
# INR    128969
# Name: currency, dtype: int64

# %%
df["Qty"].value_counts()
# Out:
# 1     115777
# 0      12804
# 2        341
# 3         32
# 4          9
# 5          2
# 15         1
# 9          1
# 13         1
# 8          1
# Name: Qty, dtype: int64

# %%
df["ASIN"].value_counts()
# Out:
# B09SDXFFQ1    773
# B09SDY8DCT    657
# B09SDYQ3WG    587
# B081WSCKPQ    535
# B08XNJG8B1    506
#              ...
# B08QGLTM6G      1
# B08W8DBLXF      1
# B09TL1F68S      1
# B07MY3MVW3      1
# B07N81TFNY      1
# Name: ASIN, Length: 7190, dtype: int64

# %%
df["SKU"].value_counts()
# Out:
# JNE3797-KR-L       773
# JNE3797-KR-M       657
# JNE3797-KR-S       587
# JNE3405-KR-L       535
# J0230-SKD-M        506
#                   ...
# BTM004-XXXL          1
# BL090-XS             1
# BTM045-PP-M          1
# SET034-KR-NP-XS      1
# SET045-KR-NP-M       1
# Name: SKU, Length: 7195, dtype: int64

# %%
np.unique(df["Courier Status"])
# Out:
# array(['Cancelled', 'Shipped', 'Unshipped'], dtype=object)

# %%
df.drop(["promotion-ids","ship-postal-code","currency"],axis=1,inplace=True)
df.sample()
# Out:
#                  Order ID      Date                        Status Fulfilment  \
# 2089  406-5835066-8509123  04-29-22  Shipped - Delivered to Buyer   Merchant
#
#      Sales Channel  ship-service-level    Style             SKU Category Size  \
# 2089      Amazon.in           Standard  JNE3703  JNE3703-KR-XXL    kurta  XXL
#
#             ASIN Courier Status  Qty  Amount   ship-city      ship-state  \
# 2089  B099FDH3P2        Shipped    1   316.0  ANAKAPALLE  ANDHRA PRADESH
#
#      ship-country
# 2089           IN

# %% [markdown]
# # En çok satış yapan kategoriler

# %%
best_selling_category=df.groupby('Category')["Amount"].sum().sort_values(ascending=False).head()
print(best_selling_category)
# Out:
# Category
# Set              40495181.03
# kurta            22559055.70
# Western Dress    11533676.69
# Top               5530135.30
# Ethnic Dress       817551.66
# Name: Amount, dtype: float64

# %%
best_selling_category.plot(kind='bar', color='skyblue', figsize=(8, 5))
plt.title('En Çok Satış Yapan 5 Kategori')
plt.xlabel('Kategori')
plt.ylabel('Toplam Satış (Amount)')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
best_category=df.groupby("Category")["Amount"].sum().sort_values(ascending=False)
plt.figure(figsize=(15,8))
ax=sbn.barplot(x=best_category.values, y=best_category.index, data=df)
plt.title("Total Amount ($) by Categorys")
plt.xticks(rotation=45)
plt.grid(axis="y")

for container in ax.containers:
    ax.bar_label(container)

plt.show()

# %%
top_5_cities = df['ship-city'].value_counts().nlargest(5).index
df_top_cities = df[df['ship-city'].isin(top_5_cities)]
plt.figure(figsize=(15,8))
ax = sbn.countplot(data=df_top_cities, x="Category", hue="ship-city", palette='tab10')  
plt.title("Category order by Top 5 Ship Cities")
plt.xticks(rotation=45)
plt.grid(axis="y")

for container in ax.containers:
    ax.bar_label(container)

plt.show()

# %%
df["Size"].value_counts()
# Out:
# M       22709
# L       22130
# XL      20875
# XXL     18096
# S       17090
# 3XL     14815
# XS      11161
# 6XL       738
# 5XL       550
# 4XL       427
# Free      378
# Name: Size, dtype: int64

# %%
top_5_category = df['Category'].value_counts().nlargest(5).index
df_top_category = df[df['Category'].isin(top_5_category)]
plt.figure(figsize=(15,8))
ax = sbn.countplot(data=df_top_category, x="Category", hue="Size", palette='tab10')  
plt.title("Category order by Size")
plt.xticks(rotation=45)
plt.grid(axis="y")

for container in ax.containers:
    ax.bar_label(container)

plt.show()

# %%
plt.figure(figsize=(10,6))
sbn.histplot(data=df, x="Amount", hue="Category", bins=30, kde=True, palette="BrBG")
plt.title("Histogram of Amount by Category")
plt.xlabel("Amount")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Tarihe göre en çok satılan ürünler

# %%
sales_Date = df.groupby('Date')['Amount'].sum()
print(sales_Date)
# Out:
# Date
# 03-31-22     105274.85
# 04-01-22     908570.60
# 04-02-22     952602.53
# 04-03-22    1051264.38
# 04-04-22     918368.17
#                ...
# 06-25-22     678972.58
# 06-26-22     795156.02
# 06-27-22     736468.67
# 06-28-22     802409.53
# 06-29-22     423101.76
# Name: Amount, Length: 91, dtype: float64

# %%
df["month"].unique()
# Out:
# array(['April', 'March', 'May', 'June'], dtype=object)

# %%
df["Date"]=pd.to_datetime(df["Date"])
df["month"]=df["Date"].dt.month_name()
plt.figure(figsize=(10,5))
month_order = [ 'March', 'April', 'May', 'June']
monthly_sales = df.groupby('month')['Amount'].sum().reindex(month_order, fill_value=0)
ax = monthly_sales.plot(kind='line', marker='o', color='#D2691E')
ax.set_title("Total Amount ($) by Months")
ax.set_xlabel("Month")
ax.set_ylabel("Total Amount ($)")
ax.set_xticks(range(len(month_order)))
ax.set_xticklabels(month_order, rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
weekly_sales = df.groupby(pd.Grouper(key='Date', freq='W'))['Amount'].sum()
plt.figure(figsize=(12, 5))
weekly_sales.plot()
plt.title('Haftalık Satış Tutarı')
plt.xlabel('Tarih')
plt.ylabel('Toplam Satış (Amount)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Şehirlere göre en çok satılan Kategoriler

# %%
city_sales=df.groupby("ship-city")["Amount"].sum().sort_values(ascending=False).head()
print(city_sales)
# Out:
# ship-city
# BENGALURU    7081002.99
# HYDERABAD    5132764.82
# MUMBAI       3807802.80
# NEW DELHI    3751529.78
# CHENNAI      3214854.74
# Name: Amount, dtype: float64

# %%
city_sales.plot()
plt.title('Şehirlerin Satış Tutarı')
plt.xlabel('Şehir')
plt.ylabel('Toplam Satış (Amount)')
plt.show()

# %%
df.columns = df.columns.str.strip()
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.columns
# Out:
# Index(['Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'Amount', 'ship-city', 'ship-state',
#        'ship-country', 'month'],
#       dtype='object')

# %% [markdown]
# # Durumlara göre sipariş sayısı

# %%
status_counts = df['Status'].value_counts()

plt.figure(figsize=(12, 10))
status_counts.plot(kind='bar', color='#73361C')
plt.title('Order Count by Status')
plt.xlabel('Status')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Satışlara göre Şehirler

# %%
city_sales=df["ship-city"].value_counts().nlargest(10)
plt.figure(figsize=(8, 8))
plt.pie(city_sales, 
        labels=city_sales.index, 
        autopct='%1.1f%%', 
        startangle=140
        )

plt.title('Top 10 Shipping Cities by Order Count')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
sbn.kdeplot(df["Amount"], fill=True, color="#73361C")
plt.title("Density Plot of Amount")
plt.xlabel("Amount")
plt.ylabel("Density")
plt.show()

# %%
df.sample()
# Out:
#                   Order ID       Date   Status Fulfilment Sales Channel  \
# 24310  407-3442815-5034700 2022-04-16  Shipped     Amazon     Amazon.in
#
#       ship-service-level    Style           SKU Category Size        ASIN  \
# 24310          Expedited  JNE3291  JNE3291-KR-L    kurta    L  B07R5X9WJB
#
#       Courier Status  Qty  Amount ship-city   ship-state ship-country  month
# 24310        Shipped    1   442.0    KALYAN  MAHARASHTRA           IN  April

# %%
df["Qty"].value_counts().reset_index()
# Out:
#    index     Qty
# 0      1  115777
# 1      0   12804
# 2      2     341
# 3      3      32
# 4      4       9
# 5      5       2
# 6     15       1
# 7      9       1
# 8     13       1
# 9      8       1

# %%
plt.figure(figsize=(20, 8))
ax=sbn.countplot(y="Qty",data=df)
plt.title('Number of Quantity orders')
plt.xticks(rotation=45)
for container in ax.containers:
    ax.bar_label(container)
plt.show()

# %%
df["ship-service-level"].value_counts().reset_index()
# Out:
#        index  ship-service-level
# 0  Expedited               88609
# 1   Standard               40360

# %%
ship=df["ship-service-level"].value_counts()
plt.figure(figsize=(8,8))
colors = ['#FF9999', '#66B3FF', '#99FF99', '#FFCC99', '#C2C2F0', 
          '#FFB6C1', '#B0E0E6', '#FFD700', '#E6E6FA', '#98FB98']
plt.pie(ship , labels=ship.index , autopct="%1.1f%%" , startangle=140 , colors=colors)
plt.title("Ship Service")
plt.tight_layout()
plt.show()

# %%
df["ship-state"].value_counts().reset_index()
# Out:
#                      index  ship-state
# 0              MAHARASHTRA       22292
# 1                KARNATAKA       17325
# 2               TAMIL NADU       11483
# 3                TELANGANA       11330
# 4            UTTAR PRADESH       10637
# ..                     ...         ...
# 64                 Mizoram           1
# 65                rajsthan           1
# 66  Punjab/Mohali/Zirakpur           1
# 67                Rajsthan           1
# 68                  orissa           1
#
# [69 rows x 2 columns]

# %%
topship_city=df["ship-state"].value_counts().sort_values(ascending=False).head(10)
plt.figure(figsize=(20, 8))
ax=sbn.countplot(x="ship-state",data=df)
plt.title('Number of Orders by Customer Location')
plt.xlabel('Customer Location')
plt.ylabel('Number of Orders')
plt.xticks(rotation=90)
for container in ax.containers:
    ax.bar_label(container)
plt.show()
